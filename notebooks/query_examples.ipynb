# %% [markdown]
# Here are examples of some queries that I wrote. They are too complex. Potentially run each cell type separately?

# %%
    query = f"""OPEN_ACCESS:Y AND PUB_YEAR:[{start_year} TO {current_year}] AND (
                "bone marrow" OR "peripheral blood" OR "blood sample" 
                OR "blood samples" OR "blood cell" OR "blood cells" OR 
                "blood mononuclear cell" OR "blood mononuclear cells" OR
                "hematopoietic cell" OR "hematopoietic cells" OR 
                "hematopoietic stem cell" OR "hematopoietic stem cells" OR
                "leukocyte" OR "leukocytes" OR "white blood cell" OR 
                "white blood cells" OR "WBC" OR "WBCs" OR    
                "lymphocyte" OR "lymphocytes" OR 
                "T lymphocyte" OR "T lymphocytes" OR
                "B lymphocyte" OR "B lymphocytes" OR
                "basophil" OR "basophils" OR
                "eosinophil" OR "eosinophils" OR
                "neutrophil" OR "neutrophils" OR

                "monocyte" OR "monocytes" OR
                "classical monocyte" OR "classical monocytes" OR
                "intermediate monocyte" OR "intermediate monocytes" OR
                "nonclassical monocyte" OR "non-classical monocyte" OR
                "nonclassical monocytes" OR "non-classical monocytes" OR

                "dendritic cell" OR "dendritic cells" OR "DC" OR "DCs" OR
                "myeloid dendritic cell" OR "myeloid dendritic cells" OR "mDC"
                OR "mDCs" OR "plasmacytoid dendritic cell" OR
                "plasmacytoid dendritic cells" OR "pDC" OR "pDCs" OR
                "B cell" OR "B-cell" OR "B cells" OR "B-cells" OR
                "naive B cell" OR "naive B-cell" OR "naive B cells" OR "naive B-cells" OR
                "memory B cell" OR "memory B-cell" OR "memory B cells" OR "memory B-cells" OR

                "NK cell" OR "NK-cell" OR "natural killer cell" 
                OR "natural killer cells" OR "NK cells" OR "NK-cells" OR
                "bright NK cell" OR "dim NK cell"

                "T cell" OR "T-cell" OR "T cells" OR "T-cells" OR
                
                "CD4 T cell" OR "CD4 T-cell" OR "CD4+ T cell" OR "CD4+ T-cell"
                OR "CD4 positive T cell" OR
                "CD4 T cells" OR "CD4 T-cells" OR "CD4+ T cells"
                OR "CD4+ T-cells" OR "CD4 positive T cells" OR
                "naive CD4 T cell" OR "naive CD4+ T cell" OR "naive CD4 T-cell"
                OR "naive CD4+ T-cell" OR "central memory CD4 T cell" OR
                "central memory CD4+ T cell" OR "effector memory CD4 T cell" 
                OR "effector memory CD4+ T cell" OR
                "TEMRA CD4 T cell" OR "TEMRA CD4+ T cell" OR
                "regulatory T cell" OR "regulatory T-cell" OR "Treg" OR "Tregs" OR
                "T follicular helper cell" OR "T follicular helper cells" OR "Tfh" OR
                "Th1 cell" OR "Th1 cells" OR "Th2 cell" OR "Th2 cells" OR "Th17 cell" OR "Th17 cells" OR

                "CD8 T cell" OR "CD8 T-cell" OR "CD8+ T cell" OR "CD8+ T-cell" OR "CD8 positive T cell" OR
                "CD8 T cells" OR "CD8 T-cells" OR "CD8+ T cells" OR "CD8+ T-cells" OR "CD8 positive T cells" OR
                "naive CD8 T cell" OR "naive CD8+ T cell" OR "central memory CD8 T cell" OR "central memory CD8+ T cell" OR
                "effector memory CD8 T cell" OR "effector memory CD8+ T cell" OR "TEMRA CD8 T cell" OR "TEMRA CD8+ T cell" 
                ) AND (
                        human OR "Homo sapiens"
                    ) NOT (
                        mouse OR murine OR "cell line" OR "COVID-19" OR "disease" OR
                        "tumor" OR "cancer" OR "leukemia"
                    )
    """

# %%
query = f"""OPEN_ACCESS:Y AND PUB_YEAR:[{start_year} TO {current_year}] AND (
        JOURNAL:"Blood" OR JOURNAL:"Blood Advances" OR JOURNAL:"British Journal of Haematology" OR
        JOURNAL:"Experimental Hematology" OR JOURNAL:"Stem Cell Reports" OR JOURNAL:"Cell Reports" OR
        JOURNAL:"Cell Stem Cell" OR JOURNAL:"Nature Communications" OR JOURNAL:"Transfusion" OR
        JOURNAL:"Frontiers in Hematology" OR JOURNAL:"Annals of Hematology" OR
        JOURNAL:"Transfusion Medicine Reviews" OR JOURNAL:"Nature Medicine" OR
        JOURNAL:"Nature Biotechnology" OR JOURNAL:"Nature Methods"
    ) AND (
  "Basophil" OR "Basophils" OR
  "Eosinophil" OR "Eosinophils" OR
  "Neutrophil" OR "Neutrophils" OR

  "Monocyte" OR "Monocytes" OR
  "Classical monocyte" OR "Classical monocytes" OR
  "Intermediate monocyte" OR "Intermediate monocytes" OR
  "Nonclassical monocyte" OR "Non-classical monocyte" OR "Nonclassical monocytes" OR "Non-classical monocytes" OR

  "Dendritic cell" OR "Dendritic cells" OR "DC" OR "DCs" OR
  "Myeloid dendritic cell" OR "Myeloid dendritic cells" OR "mDC" OR "mDCs" OR
  "Plasmacytoid dendritic cell" OR "Plasmacytoid dendritic cells" OR "pDC" OR "pDCs" OR

  "B cell" OR "B-cell" OR "B cells" OR "B-cells" OR
  "Naive B cell" OR "Naive B-cell" OR "Naive B cells" OR "Naive B-cells" OR
  "Memory B cell" OR "Memory B-cell" OR "Memory B cells" OR "Memory B-cells" OR

  "NK cell" OR "NK-cell" OR "Natural killer cell" OR "Natural killer cells" OR "NK cells" OR "NK-cells" OR
  "CD56bright NK cell" OR "CD56 bright NK cell" OR "CD56bright NK cells" OR "CD56 bright NK cells" OR
  "CD56dim NK cell" OR "CD56 dim NK cell" OR "CD56dim NK cells" OR "CD56 dim NK cells" OR

  "CD4 T cell" OR "CD4 T-cell" OR "CD4+ T cell" OR "CD4+ T-cell" OR "CD4 positive T cell" OR
  "CD4 T cells" OR "CD4 T-cells" OR "CD4+ T cells" OR "CD4+ T-cells" OR "CD4 positive T cells" OR
  "Naive CD4 T cell" OR "Naive CD4+ T cell" OR "Naive CD4 T-cell" OR "Naive CD4+ T-cell" OR
  "Central memory CD4 T cell" OR "Central memory CD4+ T cell" OR "Effector memory CD4 T cell" OR "Effector memory CD4+ T cell" OR
  "TEMRA CD4 T cell" OR "TEMRA CD4+ T cell" OR
  "Regulatory T cell" OR "Regulatory T-cell" OR "Treg" OR "Tregs" OR
  "T follicular helper cell" OR "T follicular helper cells" OR "Tfh" OR
  "Th1 cell" OR "Th1 cells" OR "Th2 cell" OR "Th2 cells" OR "Th17 cell" OR "Th17 cells" OR

  "CD8 T cell" OR "CD8 T-cell" OR "CD8+ T cell" OR "CD8+ T-cell" OR "CD8 positive T cell" OR
  "CD8 T cells" OR "CD8 T-cells" OR "CD8+ T cells" OR "CD8+ T-cells" OR "CD8 positive T cells" OR
  "Naive CD8 T cell" OR "Naive CD8+ T cell" OR "Central memory CD8 T cell" OR "Central memory CD8+ T cell" OR
  "Effector memory CD8 T cell" OR "Effector memory CD8+ T cell" OR "TEMRA CD8 T cell" OR "TEMRA CD8+ T cell" OR

  "Gamma delta T cell" OR "Gamma-delta T cell" OR "γδ T cell" OR "γδ T cells" OR
  "Gamma delta T cells" OR "Gamma-delta T cells" OR "Tγδ" OR "T-gamma-delta" OR

  "MAIT cell" OR "MAIT cells" OR "Mucosal-associated invariant T cell" OR "Mucosal associated invariant T cell" OR
  "Mucosal-associated invariant T cells" OR "Mucosal associated invariant T cells"
) AND (
        human OR "Homo sapiens"
    ) NOT (
        mouse OR murine OR "cell line" OR "COVID-19" OR "disease" OR
        "tumor" OR "cancer" OR "leukemia"
    )
    """
